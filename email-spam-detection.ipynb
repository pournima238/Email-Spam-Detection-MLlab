# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("spam.csv")

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 5477  ham  What Today-sunday..sunday is holiday..so no wo...        NaN
# 2565  ham  I told her I had a Dr appt next week. She thin...        NaN
# 2745  ham                      R �_ going 4 today's meeting?        NaN
# 4479  ham  Y cant u try new invention to fly..i'm not jok...        NaN
# 3957  ham         So i could kiss and feel you next to me...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5477        NaN        NaN
# 2565        NaN        NaN
# 2745        NaN        NaN
# 4479        NaN        NaN
# 3957        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
#1.Data Cleaning
#2.EDA
#3.TEXT PROCESSING
#4.MODEL BUILDING
#5.EVALUATION
#6.IMPROVEMENT
#7.WEBSITE
#8.DEPLOY

# %% [markdown]
# # 1.Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
#drop last 3 cols
df.drop(columns=['Unnamed: 2', 'Unnamed: 3','Unnamed: 4'], inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 2450  ham                            K..give back my thanks.
# 1473  ham  Will do, you gonna be at blake's all night? I ...
# 5151  ham  No problem with the renewal. I.ll do it right ...
# 273   ham              Usf I guess, might as well take 1 car
# 1359  ham  &lt;#&gt; %of pple marry with their lovers... ...

# %%
#renaming the cols
df.rename(columns={'v1':'target','v2':'text'}, inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 443     ham                             Sorry, I'll call later
# 3483    ham  Tell my  bad character which u Dnt lik in me. ...
# 1576    ham  No. To be nosy I guess. Idk am I over reacting...
# 2541    ham    I dont. Can you send it to me. Plus how's mode.
# 642     ham               Probably gonna swing by in a wee bit

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
#missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
#remove duplicates
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# #  2.EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
#data is imbalanced

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\python39\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\python39\lib\site-packages (from nltk) (2022.9.13)
# Requirement already satisfied: click in c:\python39\lib\site-packages (from nltk) (8.0.1)
# Requirement already satisfied: tqdm in c:\python39\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\python39\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\python39\lib\site-packages (from click->nltk) (0.4.4)
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Pournima
# [nltk_data]     Thakare\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters']=df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
#num of words
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.923776    18.454246       1.948152
# std         58.174846    13.325668       1.363792
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
# ham
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.456820    17.120903       1.799601
# std         56.356802    13.493725       1.278465
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.479326   27.675345       2.975498
# std         30.014336    7.011513       1.487993
# min         13.000000    2.000000       1.000000
# 25%        131.000000   25.000000       2.000000
# 50%        148.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        223.000000   46.000000       8.000000

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\python39\lib\site-packages (0.12.0)
# Requirement already satisfied: matplotlib>=3.1 in c:\python39\lib\site-packages (from seaborn) (3.4.2)
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy>=1.17 in c:\python39\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: pandas>=0.25 in c:\python39\lib\site-packages (from seaborn) (1.2.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\python39\lib\site-packages (from matplotlib>=3.1->seaborn) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python39\lib\site-packages (from matplotlib>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib>=3.1->seaborn) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python39\lib\site-packages (from matplotlib>=3.1->seaborn) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib>=3.1->seaborn) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in c:\python39\lib\site-packages (from pandas>=0.25->seaborn) (2021.1)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from cycler>=0.10->matplotlib>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <AxesSubplot:xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <AxesSubplot:xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3.Data Preprocessing

# %% [markdown]
# 1.Lower case
# 2.Tokenization
# 3.Removing special Characters
# 4.Removing stop words and punctuation
# 5.stemming

# %%
import nltk
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Pournima
# [nltk_data]     Thakare\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    
            
    return " ".join(y)

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\python39\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: matplotlib in c:\python39\lib\site-packages (from wordcloud) (3.4.2)
# Requirement already satisfied: pillow in c:\python39\lib\site-packages (from wordcloud) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9941

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35295

# %%
#text vectorization
#using bag of words
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %% [markdown]
# # 4.Model Building

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\python39\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\python39\lib\site-packages (from sklearn) (1.0)
# Requirement already satisfied: joblib>=0.11 in c:\python39\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\python39\lib\site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\python39\lib\site-packages (from scikit-learn->sklearn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python39\lib\site-packages (from scikit-learn->sklearn) (3.0.0)
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB, BernoulliNB

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train, y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8704061895551257
# [[788 108]
#  [ 26 112]]
# 0.509090909090909

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.971953578336557
# [[896   0]
#  [ 29 109]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
